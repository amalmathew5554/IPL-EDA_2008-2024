# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
ipl = pd.read_csv('IPL Matches Data (2008 - 2024).csv')

# %%
#Checking the starting rows
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
#Checking the ending rows
ipl.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
#Checking rows and columns
ipl.shape
# Out:
# (1095, 20)

# %%
#Data types and missing values
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
#checking for missing values
ipl.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
ipl.drop(['method'], axis=1, inplace=True)

# %%
ipl.dropna(subset=['winner'], inplace=True)

# %%
ipl.dropna(subset=['target_runs', 'target_overs'], inplace=True)

# %%
ipl['result_margin'] = ipl['result_margin'].fillna(0)

# %%
ipl['player_of_match'] = ipl['player_of_match'].fillna('Unknown')
ipl['city'] = ipl['city'].fillna('Unknown')

# %%
ipl.shape
# Out:
# (1090, 19)

# %%
ipl.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.090000e+03    1090.000000  1090.000000   1090.000000
# mean   9.046681e+05      17.037615   165.757798     19.772661
# std    3.680153e+05      21.734086    33.305775      1.517969
# min    3.359820e+05       0.000000    43.000000      5.000000
# 25%    5.483312e+05       5.000000   146.000000     20.000000
# 50%    9.809620e+05       8.000000   166.000000     20.000000
# 75%    1.254063e+06      19.750000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
#Remove duplicates
print("Duplicate rows:", ipl.duplicated().sum())
ipl.drop_duplicates(inplace=True)
# Out:
# Duplicate rows: 0

# %%
#Convert data types
ipl['date'] = pd.to_datetime(ipl['date'])

# %%
#Cleaned dataset
ipl.to_csv("ipl_cleaned.csv", index=False)

# %%
ipl=pd.read_csv('ipl_cleaned.csv')

# %%
#Top 10 player of match
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# AD Russell        15
# Name: count, dtype: int64

# %%
#Checking player of the match count for individual player
ipl['player_of_match'].value_counts()['SV Samson']
# Out:
# np.int64(11)

# %%
list(ipl['player_of_match'].value_counts()[0:5].keys())
# Out:
# ['AB de Villiers', 'CH Gayle', 'RG Sharma', 'DA Warner', 'V Kohli']

# %%
#Checking result column
ipl['result'].value_counts()
# Out:
# result
# wickets    578
# runs       498
# tie         14
# Name: count, dtype: int64

# %%
#Modifying duplicate team name
ipl['toss_winner'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)
ipl['winner'].replace({'Rising Pune Supergiant':'Rising Pune Supergiants'}, inplace=True)

# %%
#Checking ipl toss winners
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 143
# Kolkata Knight Riders          122
# Chennai Super Kings            121
# Rajasthan Royals               118
# Royal Challengers Bangalore    112
# Sunrisers Hyderabad             88
# Kings XI Punjab                 85
# Delhi Daredevils                79
# Delhi Capitals                  50
# Deccan Chargers                 43
# Punjab Kings                    24
# Gujarat Titans                  22
# Pune Warriors                   20
# Lucknow Super Giants            19
# Gujarat Lions                   15
# Rising Pune Supergiants         13
# Kochi Tuskers Kerala             8
# Royal Challengers Bengaluru      8
# Name: count, dtype: int64

# %%
#Checking matches played per season
plt.figure(figsize=(10,6))
ax=sns.countplot(x='season', data=ipl, hue='season', palette='viridis')
for container in ax.containers:
    ax.bar_label(container)
plt.title('Matches Played per Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45)
plt.legend([],[],frameon='false')
plt.show()

# %%
#Matches won by each team
plt.figure(figsize=(12,6))
ipl['winner'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Total Matches Won by Each Team')
plt.xlabel('Team')
plt.ylabel('Wins')
plt.xticks(rotation=75)
plt.show()

# %%
#Toss decision preference
plt.figure(figsize=(6,6))
ipl['toss_decision'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['orange','lightblue'])
plt.title('Toss Decision Preference')
plt.ylabel('')
plt.show()

# %%
#Toss winner vs Match winner
toss_match_win = (ipl['toss_winner'] == ipl['winner']).value_counts()
plt.figure(figsize=(6,6))
toss_match_win.plot(kind='pie', labels=['Toss Win = Match Win', 'Toss Win ≠ Match Win'], autopct='%1.1f%%', colors=['green','red'])
plt.title('Impact of Toss on Match Result')
plt.ylabel('')
plt.show()

# %%
#Player of the Match Leaders
plt.figure(figsize=(12,6))
ipl['player_of_match'].value_counts().head(10).plot(kind='bar', color='purple')
plt.title('Top 10 Players of the Match Awards')
plt.xlabel('Player')
plt.ylabel('Awards')
plt.xticks(rotation=60)
plt.show()

# %%
#Matches by venue
plt.figure(figsize=(14,6))
ipl['venue'].value_counts().head(10).plot(kind='bar', color='teal')
plt.title('Top 10 Venues by Matches Hosted')
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.xticks(rotation=75)
plt.show()

# %%
#Match result typs
plt.figure(figsize=(6,6))
ipl['result'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen','lightcoral','skyblue'])
plt.title('Match Result Types')
plt.ylabel('')
plt.show()

# %%
#Top 10 cities by matches hosted
plt.figure(figsize=(12,6))
ipl['city'].value_counts().head(10).plot(kind='bar', color='seagreen')
plt.title('Top 10 Cities by Matches Hosted')
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.xticks(rotation=75)
plt.show()

# %%
#Team Performance in Finals
plt.figure(figsize=(10,6))
ax=sns.countplot(y='winner', data=finals, order=finals['winner'].value_counts().index, hue = 'winner', palette='coolwarm')
for container in ax.containers:
    ax.bar_label(container,label_type='edge',padding=3)
plt.title('IPL Final Wins by Team')
plt.xlabel('Number of Titles')
plt.ylabel('Team')
plt.show()

# %%
#Season wise number of teams participating
teams_per_season = ipl.groupby('season')['team1'].nunique()
plt.figure(figsize=(10,6))
teams_per_season.plot(kind='bar', color='teal')
plt.title('Number of Teams per IPL Season')
plt.xlabel('Season')
plt.ylabel('Unique Teams')
plt.show()

# %%
#Team vs Venue win Heatmap
venue_wins = ipl.pivot_table(index='venue', columns='winner', values='id', aggfunc='count')
plt.figure(figsize=(14,10))
sns.heatmap(venue_wins.fillna(0), cmap='YlGnBu')
plt.title('Team Wins by Venue')
plt.xlabel('Team')
plt.ylabel('Venue')
plt.show()

# %%
#Season-wise Player of the Match Awards
pom_per_season = ipl.groupby(['season'])['player_of_match'].value_counts().groupby(level=0).head(1)
pom_per_season.plot(kind='bar', figsize=(12,6), color='coral')
plt.title('Most Player of the Match Awards per Season')
plt.ylabel('Count')
plt.show()

# %%
#Donut Chart – Top 5 Winning Teams
top5 = ipl['winner'].value_counts().head(5)
plt.figure(figsize=(8,8))
plt.pie(top5, labels=top5.index, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.5))
plt.title('Top 5 Teams by Total Wins')
plt.show()
